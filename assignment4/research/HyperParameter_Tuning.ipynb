# %%
from pathlib import Path

PATH_DATA = Path().resolve() / 'data'
PATH_DATA.mkdir(exist_ok=True)

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 250 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 58.4 MB/s
# ...
#      |████████████████████████████████| 9.2 MB 49.7 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 54.6 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 51.7 MB/s
# ...
#      |████████████████████████████████| 441 kB 59.1 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 48.5 MB/s
# ...
#      |████████████████████████████████| 163 kB 52.0 MB/s
# ...
#      |████████████████████████████████| 182 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 166 kB 58.5 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 166 kB 72.2 MB/s
# ...
#      |████████████████████████████████| 162 kB 77.0 MB/s
# ...
#      |████████████████████████████████| 162 kB 74.5 MB/s
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
df_train_olid_small = pd.read_csv(PATH_DATA / 'olid-train-small.csv')
df_train_hasoc = pd.read_csv(PATH_DATA / 'hasoc-train.csv')
df_test_olid = pd.read_csv(PATH_DATA / 'olid-test.csv')
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]

# %%
rskf=StratifiedKFold(n_splits=5,shuffle=True)
pred=[]
probabilities=[]
macro_bert=[]
Learning_rate=[5e-5, 4e-5, 3e-5, 2e-5]
ning_ratefor i in Lear:
  f1_score_bert=[]
  for train_index,test_index in rskf.split(df_train_olid_small['text'],df_train_olid_small['labels']):
    train_df=df_train_olid_small.iloc[train_index]
    test_df=df_train_olid_small.iloc[test_index]
    model=ClassificationModel("bert", "diptanu/fBERT",args={'reprocess_input_data':True,'overwrite_output_dir':True,"learning_rate": i},use_cuda=True)
    model.train_model(train_df)
    predictions,prob=model.predict(test_df.text.to_list())
    f1=f1_score(y_true=test_df['labels'],y_pred=predictions,average='macro')
    print(f1)
    f1_score_bert.append(f1)
  macro_bert.append(f1_score_bert)
# Out:
# Some weights of the model checkpoint at diptanu/fBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
macro_bert
# Out:
# [[0.7917658883562702,
#   0.7762779800454966,
#   0.7793837376332773,
#   0.7766749379652605,
#   0.7744566778212192],
#  [0.7849667531235197,
#   0.7780863153410513,
#   0.8000512689054089,
#   0.768353236957888,
#   0.7940722229798083],
#  [0.7731737745822254,
#   0.7934826099083161,
#   0.7794234502616006,
#   0.7711158792596708,
#   0.800016160310278],
#  [0.7817543101288026,
#   0.7929169344629468,
#   0.7732737151100617,
#   0.7923017134668837,
#   0.7893865207373272]]

# %%
Hyperpar_tuning_bert=[]
for i in macro_bert:
  s=sum(i)
  s1=s/5
  Hyperpar_tuning_bert.append(s1)
print(Learning_rate)
print(Hyperpar_tuning_bert)
# Out:
# [5e-05, 4e-05, 3e-05, 2e-05]
# [0.7797118443643047, 0.7851059594615353, 0.7834423748644183, 0.7859266387812045]

# %%
rskf=StratifiedKFold(n_splits=5,shuffle=True)
pred=[]
probabilities=[]
macro_fbert=[]
Learning_rate=[5e-5, 4e-5, 3e-5, 2e-5]
for i in Learning_rate:
  f1_score_fbert=[]
  for train_index,test_index in rskf.split(df_train_olid_small['text'],df_train_olid_small['labels']):
    train_df=df_train_olid_small.iloc[train_index]
    test_df=df_train_olid_small.iloc[test_index]
    model=ClassificationModel("bert", "diptanu/fBERT",args={'reprocess_input_data':True,'overwrite_output_dir':True,"learning_rate": i},use_cuda=True)
    model.train_model(train_df)
    predictions,prob=model.predict(test_df.text.to_list())
    f2=f1_score(y_true=test_df['labels'],y_pred=predictions,average='macro')
    print(f2)
    f1_score_fbert.append(f2)
  macro_fbert.append(f1_score_fbert)
# Out:
# Some weights of the model checkpoint at diptanu/fBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
macro_fbert
# Out:
# [[0.7895747062827192,
#   0.7517505409062284,
#   0.77123745819398,
#   0.7938187738603188,
#   0.7847775277008311],
#  [0.7966551741557424,
#   0.7675322117841593,
#   0.7919941612396139,
#   0.7741381587637035,
#   0.7810464855153828],
#  [0.7904685885706462,
#   0.7619608463835044,
#   0.803582597207289,
#   0.7885594019978186,
#   0.7883947121092205],
#  [0.7827417265191634,
#   0.764088268365817,
#   0.7965507175448548,
#   0.7837559562102043,
#   0.7827142857142857]]

# %%
Hyperpar_tuning_fbert=[]
for i in macro_fbert:
  s=sum(i)
  s1=s/5
  Hyperpar_tuning_fbert.append(s1)
print(Learning_rate)
print(Hyperpar_tuning_fbert)
# Out:
# [5e-05, 4e-05, 3e-05, 2e-05]
# [0.7782318013888155, 0.7822732382917205, 0.7865932292536957, 0.781970190870865]

# %%
rskf=StratifiedKFold(n_splits=5,shuffle=True)
pred=[]
probabilities=[]
macro_hatebert=[]
Learning_rate=[5e-5, 4e-5, 3e-5, 2e-5]
for i in Learning_rate:
  f1_score_hatebert=[]
  for train_index,test_index in rskf.split(df_train_olid_small['text'],df_train_olid_small['labels']):
    train_df=df_train_olid_small.iloc[train_index]
    test_df=df_train_olid_small.iloc[test_index]
    model=ClassificationModel("bert", "GroNLP/hateBERT",args={'reprocess_input_data':True,'overwrite_output_dir':True,"learning_rate": i},use_cuda=True)
    model.train_model(train_df)
    predictions,prob=model.predict(test_df.text.to_list())
    f3=f1_score(y_true=test_df['labels'],y_pred=predictions,average='macro')
    print(f3)
    f1_score_hatebert.append(f2)
  macro_hatebert.append(f1_score_hatebert)
# Out:
# Downloading:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at GroNLP/hateBERT were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
macro_hatebert
# Out:
# [[0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857],
#  [0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857],
#  [0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857],
#  [0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857,
#   0.7827142857142857]]

# %%
Hyperpar_tuning_hatebert=[]
for i in macro_hatebert:
  s=sum(i)
  s1=s/5
  Hyperpar_tuning_hatebert.append(s1)
print(Learning_rate)
print(Hyperpar_tuning_hatebert)
# Out:
# [5e-05, 4e-05, 3e-05, 2e-05]
# [0.7827142857142857, 0.7827142857142857, 0.7827142857142857, 0.7827142857142857]
